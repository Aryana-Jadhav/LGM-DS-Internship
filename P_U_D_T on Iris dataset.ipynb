# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("/content/drive/MyDrive/LGM Internship/Iris (1).xlsx")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1              5             3              1             0        0
# 1      2              4             3              1             0        0
# 2      3              4             3              1             0        0
# 3      4              4             3              1             0        0
# 4      5              5             3              1             0        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146              6             3              5             2        2
# 146  147              6             2              5             1        2
# 147  148              6             3              5             2        2
# 148  149              6             3              5             2        2
# 149  150              5             3              5             1        2
#
# [150 rows x 6 columns]

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

data['Species']= label_encoder.fit_transform(data['Species'])
data['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
data['SepalLengthCm'] = data['SepalLengthCm'].astype('int64')
data['SepalWidthCm'] = data['SepalWidthCm'].astype('int64')
data['PetalLengthCm'] = data['PetalLengthCm'].astype('int64')
data['PetalWidthCm'] = data['PetalWidthCm'].astype('int64')
data['SepalLengthCm'] = np.array(data['SepalLengthCm'])
data['SepalWidthCm'] = np.array(data['SepalWidthCm'])
data['PetalLengthCm'] = np.array(data['PetalLengthCm'])
data['PetalWidthCm'] = np.array(data['PetalWidthCm'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    int64
#  2   SepalWidthCm   150 non-null    int64
#  3   PetalLengthCm  150 non-null    int64
#  4   PetalWidthCm   150 non-null    int64
#  5   Species        150 non-null    int64
# dtypes: int64(6)
# memory usage: 7.2 KB

# %%
features1=['Species']
features2=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
x= data[features1]
y= data[features2]
print(y)
print(x)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0                5             3              1             0
# 1                4             3              1             0
# 2                4             3              1             0
# 3                4             3              1             0
# 4                5             3              1             0
# ..             ...           ...            ...           ...
# 145              6             3              5             2
# 146              6             2              5             1
# 147              6             3              5             2
# 148              6             3              5             2
# 149              5             3              5             1
#
# [150 rows x 4 columns]
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# ...

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree = dtree.fit(x, y)

# %%
plt.figure(figsize=(10,10))
tree.plot_tree(dtree, feature_names=features1)
# Out:
# [Text(0.4, 0.8333333333333334, 'Species <= 0.5\ngini = 0.637\nsamples = 150\nvalue = [[22, 61, 54, 13, 0]\n[57, 89, 4, 0, 0]\n[50, 11, 43, 35, 11]\n[50, 71, 29, 0, 0]]'),
#  Text(0.2, 0.5, 'gini = 0.174\nsamples = 50\nvalue = [[20, 30, 0, 0, 0]\n[2, 44, 4, 0, 0]\n[50, 0, 0, 0, 0]\n[50, 0, 0, 0, 0]]'),
#  Text(0.6, 0.5, 'Species <= 1.5\ngini = 0.543\nsamples = 100\nvalue = [[2, 31, 54, 13, 0]\n[55, 45, 0, 0, 0]\n[0, 11, 43, 35, 11]\n[0, 71, 29, 0, 0]]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.344\nsamples = 50\nvalue = [[1, 25, 23, 1, 0]\n[34, 16, 0, 0, 0]\n[0, 11, 37, 2, 0]\n[0, 50, 0, 0, 0]]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.505\nsamples = 50\nvalue = [[1, 6, 31, 12, 0]\n[21, 29, 0, 0, 0]\n[0, 0, 6, 33, 11]\n[0, 21, 29, 0, 0]]')]

# %%
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")

print(f"No. of training examples: {training_data.columns}")
print(f"No. of testing examples: {testing_data.columns}")
# Out:
# No. of training examples: 120
# No. of testing examples: 30
# No. of training examples: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# No. of testing examples: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
